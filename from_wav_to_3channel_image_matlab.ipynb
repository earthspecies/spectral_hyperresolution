% %%
[x, sr] = audioread('data/fragment_6.25_7.75.wav');

% %%
size(x)
% Out:
% ans =
%
%       288001           2

% %%
sr
% Out:
% sr =
%
%       192000

% %%
q = 1;
tdeci = 300;
over = 2;
noct = 12;
minf = 1e-3;
maxf = 0.5;
result = reassignmentgw(x(1:20000, :), q, tdeci, over, noct, minf, maxf);
% Out:
% done_reassignment in 0.94425 s

% %%
imshow(full(result).', [0, max(full(result), [], 'all')])
