# %%
# %matplotlib inline
from matplotlib import pyplot as plt

import numpy as np
from linear_reassignment import create_reassigned_representation, plot_spectogram
from scipy.io import wavfile
import librosa

# %%
x, sr = librosa.load('data/fragment_6.25_7.75.wav', sr=None)

# %%
img = plt.imread('data/frg_cons_6.25_7.75_0.5.tiff')

# %%
plt.figure(figsize = (20,4))
plt.imshow(img)

# %%
plt.figure(figsize = (20,4))
plt.imshow(img[:, :, 0])

# %%
plt.figure(figsize = (20,4))
plt.imshow(img[:, :, 1])

# %%
plt.figure(figsize = (20,4))
plt.imshow(img[:, :, 2])

# %%
x.shape
# Out:
# (288001, 1)

# %%
q = 1;
tdeci = 300;
over = 6;
noct = 8;
minf = 1e-4;
maxf = 0.5;

# %%
# %%time

x = x.reshape((-1, 1))
spectogram = create_reassigned_representation(x, q, tdeci, over, noct, minf, maxf)
# Out:
# CPU times: user 8min 20s, sys: 3min 46s, total: 12min 7s
# Wall time: 2min 6s

# %%
plt.figure(figsize = (20,4))
plt.imshow(librosa.core.amplitude_to_db(spectogram.todense().T))plt.figure(figsize = (20,4))
plt.imshow(librosa.core.amplitude_to_db(spectogram.todense().T))
